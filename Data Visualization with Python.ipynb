# %% [markdown]
# # Importing our DataSet

# %%
import pandas as pd

data = pd.read_csv("BRCA.csv")

print(data)
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 336           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 337           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 338           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 339           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 340           NaN   NaN     NaN       NaN       NaN       NaN       NaN
#
#     Tumour_Stage                      Histology ER status PR status  \
# ...

# %% [markdown]
# # Printing Certain Columns from Dataset

# %%
print(data[['Gender', 'Patient_Status']])
# Out:
#      Gender Patient_Status
# 0    FEMALE          Alive
# 1    FEMALE           Dead
# 2    FEMALE          Alive
# 3    FEMALE          Alive
# 4    FEMALE           Dead
# ..      ...            ...
# 336     NaN            NaN
# 337     NaN            NaN
# 338     NaN            NaN
# 339     NaN            NaN
# 340     NaN            NaN
#
# [341 rows x 2 columns]

# %%
data.loc[data['Patient_Status']== "Dead"]
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807  0.614470 -0.031505
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680  0.520450 -0.311990
# 11   TCGA-BH-A0EA  72.0  FEMALE -0.372700   0.55549 -0.667900 -0.350700
# 18   TCGA-BH-A0DE  62.0  FEMALE  0.104640   0.70280 -0.298980  0.601030
# 25   TCGA-AC-A62Y  79.0  FEMALE -0.036229   0.79551 -0.013525  1.629900
# ..            ...   ...     ...       ...       ...       ...       ...
# 329  TCGA-AN-A04A  36.0  FEMALE  0.231800   0.61804 -0.557790 -0.517350
# 330  TCGA-A8-A085  44.0    MALE  0.732720   1.11170 -0.269520 -0.354920
# 331  TCGA-A1-A0SG  61.0  FEMALE -0.719470   2.54850 -0.150240  0.339680
# 332  TCGA-A2-A0EU  79.0  FEMALE  0.479400   2.05590 -0.531360 -0.188480
# 333  TCGA-B6-A40B  76.0  FEMALE -0.244270   0.92556 -0.418230 -0.067848
#
#     Tumour_Stage                       Histology ER status PR status  \
# ...

# %% [markdown]
# # Finding Stats from DataSet

# %%
data.describe()
# Out:
#               Age    Protein1    Protein2    Protein3    Protein4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean    58.886228   -0.029991    0.946896   -0.090204    0.009819
# std     12.961212    0.563588    0.911637    0.585175    0.629055
# min     29.000000   -2.340900   -0.978730   -1.627400   -2.025500
# 25%     49.000000   -0.358888    0.362173   -0.513748   -0.377090
# 50%     58.000000    0.006129    0.992805   -0.173180    0.041768
# 75%     68.000000    0.343598    1.627900    0.278353    0.425630
# max     90.000000    1.593600    3.402200    2.193400    1.629900

# %%
data
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 336           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 337           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 338           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 339           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 340           NaN   NaN     NaN       NaN       NaN       NaN       NaN
#
#     Tumour_Stage                      Histology ER status PR status  \
# ...

# %%
data.groupby(["Surgery_type"]).mean()
# Out:
#                                    Age  Protein1  Protein2  Protein3  Protein4
# Surgery_type
# Lumpectomy                   61.000000  0.153511  1.132050 -0.109783  0.129899
# Modified Radical Mastectomy  57.041667 -0.040462  0.818256  0.008741  0.062784
# Other                        59.400000 -0.128192  0.987188 -0.127066 -0.048148
# Simple Mastectomy            58.641791 -0.041854  0.885682 -0.154920 -0.093512

# %%
data.groupby(["Age"]).mean()
# Out:
#       Protein1  Protein2  Protein3  Protein4
# Age
# 29.0 -0.051933  0.915155 -0.650145  0.004020
# 32.0  0.125450  1.456500 -0.680300 -0.010378
# 35.0 -0.817530  1.790400 -1.041600  0.038522
# 36.0  0.260488  0.865673 -0.058627 -0.173220
# 37.0 -0.425900  1.161770  0.484005  0.327985
# 38.0 -0.203647  0.985847 -0.529990 -0.146820
# 39.0  0.067237  1.454833  0.006818 -0.528815
# 40.0 -0.061432  1.062767  0.097622 -0.419515
# 41.0  0.141737  0.421170  0.247938 -0.356048
# 42.0  0.145394  0.953034 -0.075080 -0.218543
# 43.0  0.210373  1.235657 -0.056117 -0.061262
# 44.0  0.509790  1.000168 -0.177728 -0.092082
# 45.0 -0.277902  0.955403 -0.335451 -0.258896
# 46.0 -0.000495  0.374139  0.100876  0.178256
# 47.0  0.063251  1.143840  0.020165  0.116816
# 48.0 -0.112784  0.426786  0.130507 -0.217015
# 49.0 -0.319147  0.645537 -0.063969 -0.144747
# 50.0  0.088831  1.163376 -0.177936  0.033803
# 51.0  0.014662  1.170812  0.122777 -0.437354
# 52.0  0.169288  1.677363 -0.300525  0.132026
# ...

# %% [markdown]
# # Sorting Data

# %%
data.sort_values('Age')
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 129  TCGA-AO-A03M  29.0  FEMALE -0.105680   0.93747  -0.62169  0.186370
# 153  TCGA-C8-A273  29.0  FEMALE  0.001814   0.89284  -0.67860 -0.178330
# 130  TCGA-AN-A0FF  32.0  FEMALE  0.125450   1.45650  -0.68030 -0.010378
# 212  TCGA-A8-A07J  35.0  FEMALE -0.817530   1.79040  -1.04160  0.038522
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# ..            ...   ...     ...       ...       ...       ...       ...
# 336           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 337           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 338           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 339           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 340           NaN   NaN     NaN       NaN       NaN       NaN       NaN
#
#     Tumour_Stage                       Histology ER status PR status  \
# ...

# %% [markdown]
# # Adding/Creating Columns

# %%
data['total protien'] = data['Protein1'] + data['Protein2'] + data['Protein3'] + data['Protein4']
data.head(4)
# Out:
#      Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0  TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1  TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2  TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3  TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
#
#   Tumour_Stage                      Histology ER status PR status HER2 status  \
# 0          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 1           II             Mucinous Carcinoma  Positive  Positive    Negative
# 2          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 3           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
#
#                   Surgery_type Date_of_Surgery Date_of_Last_Visit  \
# 0  Modified Radical Mastectomy       15-Jan-17          19-Jun-17
# 1                   Lumpectomy       26-Apr-17          09-Nov-18
# ...

# %% [markdown]
# # Filtering Data

# %%
data.loc[(data["ER status"] == "Positive") | (data["HER2 status"] == "Positive")]
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 329  TCGA-AN-A04A  36.0  FEMALE  0.231800   0.61804  -0.55779 -0.517350
# 330  TCGA-A8-A085  44.0    MALE  0.732720   1.11170  -0.26952 -0.354920
# 331  TCGA-A1-A0SG  61.0  FEMALE -0.719470   2.54850  -0.15024  0.339680
# 332  TCGA-A2-A0EU  79.0  FEMALE  0.479400   2.05590  -0.53136 -0.188480
# 333  TCGA-B6-A40B  76.0  FEMALE -0.244270   0.92556  -0.41823 -0.067848
#
#     Tumour_Stage                       Histology ER status PR status  \
# ...

# %%
data.loc[(data["Tumour_Stage"] == "II") & (data["Histology"] == "Mucinous Carcinoma") & (data["Age"] < 50)]
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 1    TCGA-EW-A1OX  43.0  FEMALE  -0.42032   0.57807  0.614470 -0.031505
# 16   TCGA-A2-A0D4  37.0  FEMALE   0.29490   1.36250  0.692380  0.410020
# 26   TCGA-A7-A5ZW  47.0  FEMALE   0.33186  -0.32765  0.003379  1.165800
# 239  TCGA-EW-A1P3  48.0  FEMALE  -0.34001   0.16257 -0.177200  0.412550
#
#     Tumour_Stage           Histology ER status PR status HER2 status  \
# 1             II  Mucinous Carcinoma  Positive  Positive    Negative
# 16            II  Mucinous Carcinoma  Positive  Positive    Negative
# 26            II  Mucinous Carcinoma  Positive  Positive    Negative
# 239           II  Mucinous Carcinoma  Positive  Positive    Negative
#
#           Surgery_type Date_of_Surgery Date_of_Last_Visit Patient_Status
# 1           Lumpectomy       26-Apr-17          09-Nov-18           Dead
# 16          Lumpectomy       15-Jun-17          24-Oct-18          Alive
# ...

# %%
data.loc[data["Gender"] == "FEMALE", "Gender"] = "Woman"
data
# Out:
#        Patient_ID   Age Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  Woman  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  Woman -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  Woman  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  Woman  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  Woman  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...    ...       ...       ...       ...       ...
# 336           NaN   NaN    NaN       NaN       NaN       NaN       NaN
# 337           NaN   NaN    NaN       NaN       NaN       NaN       NaN
# 338           NaN   NaN    NaN       NaN       NaN       NaN       NaN
# 339           NaN   NaN    NaN       NaN       NaN       NaN       NaN
# 340           NaN   NaN    NaN       NaN       NaN       NaN       NaN
#
#     Tumour_Stage                      Histology ER status PR status  \
# ...
